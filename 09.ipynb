# %%
# ch11 01.ipynb

# %%
# 라이브러리 gensim
# 사전학습모델 로드 Glove wiki gigaword-50
# 단어벡터 추출 및 기본 정보 확인
# 벡터 연산을 통한 의미관계 분석
# 문장수준의 유사도 계산

# %%
# Count-based 방법
# cat dog가 함께 나타나는 횟수를 카운트

# Prediction-based word2vec
# cat 주변 단어로부트 dog를 예측하도록 학습

# 이두가지 방법을 결합한게 Glove Count 통계 + 벡터 학습의 최적화 결과
